# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\gurra\anaconda3\jupyter\lib\site-packages (1.5.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\gurra\anaconda3\jupyter\lib\site-packages (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\gurra\anaconda3\jupyter\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\gurra\anaconda3\jupyter\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\gurra\Downloads\covid.csv")

# %%
data.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# 1                       0.0  ...         13.085          7.452
# 2                       0.0  ...         13.085          7.452
# 3                       0.0  ...         13.085          7.452
# 4                       0.0  ...         13.085          7.452
#
#    gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 0       35973.781              NaN             NaN                11.62
# 1       35973.781              NaN             NaN                11.62
# 2       35973.781              NaN             NaN                11.62
# 3       35973.781              NaN             NaN                11.62
# 4       35973.781              NaN             NaN                11.62
#
#    female_smokers male_smokers  handwashing_facilities  hospital_beds_per_100k
# 0             NaN          NaN                     NaN                     NaN
# 1             NaN          NaN                     NaN                     NaN
# 2             NaN          NaN                     NaN                     NaN
# 3             NaN          NaN                     NaN                     NaN
# 4             NaN          NaN                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
data.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 19491             4           0                      NaN
# 19492             6           2                      NaN
# 19493             6           0                      NaN
# 19494             6           0                      NaN
# 19495             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19491                    NaN                       NaN  ...            NaN
# 19492                    NaN                       NaN  ...            NaN
# 19493                    NaN                       NaN  ...            NaN
# 19494                    NaN                       NaN  ...            NaN
# 19495                    NaN                       NaN  ...            NaN
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 19491            NaN             NaN              NaN             NaN
# 19492            NaN             NaN              NaN             NaN
# 19493            NaN             NaN              NaN             NaN
# 19494            NaN             NaN              NaN             NaN
# 19495            NaN             NaN              NaN             NaN
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 19491                  NaN             NaN          NaN
# 19492                  NaN             NaN          NaN
# 19493                  NaN             NaN          NaN
# 19494                  NaN             NaN          NaN
# 19495                  NaN             NaN          NaN
#
#        handwashing_facilities  hospital_beds_per_100k
# 19491                     NaN                     NaN
# 19492                     NaN                     NaN
# 19493                     NaN                     NaN
# 19494                     NaN                     NaN
# 19495                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (19496, 32)

# %%
data.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
data['location'].value_counts()
# Out:
# Sweden            146
# Canada            146
# United States     146
# Lithuania         146
# Brazil            146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %%
data.describe(include='O')
# Out:
#         iso_code location        date      tests_units
# count      19432    19496       19496             6229
# unique       211      212         146                5
# top     OWID_WRL   Sweden  2020-05-18  tests performed
# freq         146      146         211             2462

# %%
data.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# aged_70_older                       True
# gdp_per_capita                      True
# extreme_poverty                     True
# cvd_death_rate                      True
# diabetes_prevalence                 True
# female_smokers                      True
# male_smokers                        True
# handwashing_facilities              True
# hospital_beds_per_100k              True
# dtype: bool

# %%
data.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# aged_70_older                       1832
# gdp_per_capita                      1982
# extreme_poverty                     7878
# cvd_death_rate                      1817
# diabetes_prevalence                 1174
# female_smokers                      5052
# male_smokers                        5206
# handwashing_facilities             11822
# hospital_beds_per_100k              3160
# dtype: int64

# %%
India_case=data[data['location']=="India"]

# %%
India_case.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  2019-12-31            0          0             0
# 8380      IND    India  2020-01-01            0          0             0
# 8381      IND    India  2020-01-02            0          0             0
# 8382      IND    India  2020-01-03            0          0             0
# 8383      IND    India  2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# 8380           0                      0.0                    0.0
# 8381           0                      0.0                    0.0
# 8382           0                      0.0                    0.0
# 8383           0                      0.0                    0.0
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8379                       0.0  ...          5.989          3.414
# 8380                       0.0  ...          5.989          3.414
# 8381                       0.0  ...          5.989          3.414
# 8382                       0.0  ...          5.989          3.414
# 8383                       0.0  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 8379        6426.674             21.2          282.28                10.39
# 8380        6426.674             21.2          282.28                10.39
# 8381        6426.674             21.2          282.28                10.39
# 8382        6426.674             21.2          282.28                10.39
# 8383        6426.674             21.2          282.28                10.39
#
#       female_smokers male_smokers  handwashing_facilities  \
# 8379             1.9         20.6                   59.55
# 8380             1.9         20.6                   59.55
# 8381             1.9         20.6                   59.55
# 8382             1.9         20.6                   59.55
# 8383             1.9         20.6                   59.55
#
#       hospital_beds_per_100k
# 8379                    0.53
# 8380                    0.53
# 8381                    0.53
# 8382                    0.53
# 8383                    0.53
#
# [5 rows x 32 columns]

# %%
India_case.tail()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  2020-05-20       106750       5611          3303
# 8520      IND    India  2020-05-21       112359       5609          3435
# 8521      IND    India  2020-05-22       118447       6088          3583
# 8522      IND    India  2020-05-23       125101       6654          3720
# 8523      IND    India  2020-05-24       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8519                     2.393  ...          5.989          3.414
# 8520                     2.489  ...          5.989          3.414
# 8521                     2.596  ...          5.989          3.414
# 8522                     2.696  ...          5.989          3.414
# 8523                     2.802  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 8519        6426.674             21.2          282.28                10.39
# 8520        6426.674             21.2          282.28                10.39
# 8521        6426.674             21.2          282.28                10.39
# 8522        6426.674             21.2          282.28                10.39
# 8523        6426.674             21.2          282.28                10.39
#
#       female_smokers male_smokers  handwashing_facilities  \
# 8519             1.9         20.6                   59.55
# 8520             1.9         20.6                   59.55
# 8521             1.9         20.6                   59.55
# 8522             1.9         20.6                   59.55
# 8523             1.9         20.6                   59.55
#
#       hospital_beds_per_100k
# 8519                    0.53
# 8520                    0.53
# 8521                    0.53
# 8522                    0.53
# 8523                    0.53
#
# [5 rows x 32 columns]

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = "date",y = "total_cases",data=India_case)
plt.show()

# %%
india_last_5_days=India_case.tail()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x = "date",y = "total_cases",data=india_last_5_days)
plt.show()
